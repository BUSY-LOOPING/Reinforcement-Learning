# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a1, b1 = 7, 3     #Coin tossed 10 times
a2, b2 = 70, 30   #Coin tossed 100 times
a3, b3 = 700, 300 #Coin tossed 1000 times
N = 1000

# %%
fx1 = np.random.beta(a1 + 1, b1 + 1, size = N)
fx2 = np.random.beta(a2 + 1, b2 + 1, size = N)
fx3 = np.random.beta(a3 + 1, b3 + 1, size = N)

# %%
plt.rcParams['figure.figsize'] = [12, 5]
fig, axs = plt.subplots(1, 3)
axs[0].set_title(f'Beta({a1 + 1}, {b1 + 1})')
axs[0].set_xlim(0, 1)
axs[1].set_title(f'Beta({a2 + 1}, {b2 + 1})')
axs[1].set_xlim(0, 1)
axs[2].set_title(f'Beta({a3 + 1}, {b3 + 1})')
axs[2].set_xlim(0, 1)


sns.kdeplot(fx1, ax=axs[0])
sns.kdeplot(fx2, ax=axs[1])
sns.kdeplot(fx3, ax=axs[2])
plt.show()
